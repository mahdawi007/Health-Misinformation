# %%
import csv

with open('CAD_test.csv', newline='') as f:
    reader = csv.reader(f)
    dict = list(reader)

print(dict)
# Out:
# [['ischemic heart disease'], ['Coronary artery disease'], ['Coronary heart disease'], ['CAD treatment'], ['CAD symptoms'], ['CAD signs'], ['CAD risk'], ['Coronary heart disease treatment'], ['Coronary heart disease symptoms'], ['Coronary heart disease signs'], ['Coronary heart disease risk'], ['heart disease misinformation'], ['heart disease fake news'], ['heart disease Myths'], ['heart disease facts'], ['cardiovascular diseases'], ['heart disease plaque buildup'], ['heart disease arteries '], ['heart disease CAD'], ['heart disease CHD'], ['heart attack'], ['smoking heart attack'], ['Diabetes heart attack'], ['heart attack symptoms'], ['heart attack signs'], ['heart attack risk '], ['heart attack treatment'], ['cholesterol heart disease'], ['heart Chest pain'], ['heart cold sweat'], ['heart pain'], ['heart shoulders discomfort'], ['heart Shortness of breath'], ['high blood pressure'], ['Heart Surgery'], ['Heart transplant'], ['Heart valve repair'], ['Heart surgery infections'], ['hea
# ...

# %%
import csv

with open('/content/tweets_keywords.csv', newline='') as f:
    reader = csv.reader(f)
    dict = list(reader)
#dict.remove(r"heart attack")
dict.append('heart attack symptoms')
dict.append('heart attack signs')
dict.append('heart attack reasons')

print(dict)
# Out:
# [['ischemic heart disease'], ['Coronary artery disease'], ['Coronary heart disease'], ['CAD treatment'], ['CAD symptoms'], ['CAD signs'], ['CAD risk'], ['Coronary heart disease treatment'], ['Coronary heart disease symptoms'], ['Coronary heart disease signs'], ['Coronary heart disease risk'], ['heart disease misinformation'], ['heart disease fake news'], ['heart disease Myths'], ['heart disease facts'], ['cardiovascular diseases'], ['heart disease plaque buildup'], ['heart disease arteries '], ['heart disease CAD'], ['heart disease CHD'], ['smoking heart attack'], ['Diabetes heart attack'], ['heart attack symptoms'], ['heart attack signs'], ['heart attack risk '], ['heart attack treatment'], ['cholesterol heart disease'], ['heart Chest pain'], ['heart cold sweat'], ['heart pain signs'], ['heart shoulders discomfort'], ['heart Shortness of breath'], ['heart disease blood pressure'], ['heart surgery risks'], ['heart transplant'], ['heart valve repair'], ['heart surgery infections'], ['
# ...

# %%
pip show tweepy
# Out:
# Name: tweepy
# Version: 3.10.0
# Summary: Twitter library for Python
# Home-page: https://www.tweepy.org/
# Author: Joshua Roesslein
# Author-email: tweepy@googlegroups.com
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: requests-oauthlib, requests, six
# Required-by:

# %%
#You should also be aware that the legacy standard Twitter search API (this is what api.search is calling)
#only supports searching back within the past 7 days of Tweets. For a longer period of time you will need 
#to use the Twitter premium 30-day or full-archive search APIs.

#Don't forget to update tweepy with pip install --upgrade git+https://github.com/tweepy/tweepy@master. 
#Then you can use the API with premium feature...

#See the documentation for API.search_30_day and API.search_full_archive
#and the corresponding documentation for the premium search APIs.

#The branch has been deleted since #1294 has been merged into the master branch.
#Until v3.10.0 is released, you can install from the master branch.

#for page in tweepy.Cursor(API.search_30_day, query=query, maxResults=per_page,
# environment_name="AzureDevelopment").pages(page_count):
#https://developer.twitter.com/en/account/environments

import tweepy
from datetime import datetime,timedelta
import csv
from pandas import DataFrame

access_token = "1344327509727346689-rBKxKZ7vkyhF1aeDiJ3MgDj0j5RJQX"
access_token_secret = "eHfV9kN35pV0wz8R4X2QyGQIqlI59i5oKa4UExcK9ZY2G"
consumer_key = "TbTZg3qTpc6APBqiVPKXagu44"
consumer_secret = "RDwln9OnfSNV4SIuLz37oI5KJ7SB63QPdTLpE1Q7imyY9RJgQr"

# later we need to specify fields also, filter retweets before too using fields, expand search period for testing performance using tweeby 3.10 30 days method

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

data = [] # empty list to which tweet_details obj will be added
def stream_tweets(dict):
    csvFile = open('CAD_results.csv', 'a')
    csvWriter = csv.writer(csvFile)
    counter = 0 # counter to keep track of each iteration
#search_terms = 'heart diseases'
    for keyword in dict:
        print ("[+] Checking tweets for keyword:", keyword)
        for status in tweepy.Cursor(api.search,
                       q=str(keyword) + " -filter:retweets",
                       since='2021-06-29', until='2021-07-08',
                       count=1000,
                       result_type='recent',
                       include_entities=True,
                       monitor_rate_limit=True, 
                       wait_on_rate_limit=True,
                       lang="en").items():

            eastern_time = status.created_at - timedelta(5)
            edt_time = eastern_time.strftime('%Y-%m-%d %H:%M')
            csvWriter.writerow([keyword,status.created_at, status.user.screen_name.encode('utf8'), status.text.encode('utf-8')])
            tweet_details = {}
            tweet_details['keyword'] = keyword
            tweet_details['name'] = status.user.screen_name
            tweet_details['tweet'] = status.text
            tweet_details['retweets'] = status.retweet_count
            tweet_details['location'] = status.user.location
            tweet_details['created'] = status.created_at.strftime("%d-%b-%Y")
            tweet_details['followers'] = status.user.followers_count
            tweet_details['is_user_verified'] = status.user.verified
            data.append(tweet_details)
            counter += 1
            if counter % 1000 ==0:
                print(counter)
    csvFile.close()
    print('done!')

stream_tweets(dict)
df = DataFrame (data)
print(df.shape)
df.drop_duplicates(subset ="tweet",keep = False, inplace = True)
print(df.shape)
df.head(10)
# Out:
# [+] Checking tweets for keyword: ['ischemic heart disease']
# [+] Checking tweets for keyword: ['Coronary artery disease']
# [+] Checking tweets for keyword: ['Coronary heart disease']
# [+] Checking tweets for keyword: ['CAD treatment']
# [+] Checking tweets for keyword: ['CAD symptoms']
# [+] Checking tweets for keyword: ['CAD signs']
# [+] Checking tweets for keyword: ['CAD risk']
# [+] Checking tweets for keyword: ['Coronary heart disease treatment']
# [+] Checking tweets for keyword: ['Coronary heart disease symptoms']
# [+] Checking tweets for keyword: ['Coronary heart disease signs']
# [+] Checking tweets for keyword: ['Coronary heart disease risk']
# [+] Checking tweets for keyword: ['heart disease misinformation']
# [+] Checking tweets for keyword: ['heart disease fake news']
# [+] Checking tweets for keyword: ['heart disease Myths']
# [+] Checking tweets for keyword: ['heart disease facts']
# [+] Checking tweets for keyword: ['cardiovascular diseases']
# ...

# %%
df = DataFrame (data)
print(df.shape)
df.head(10)
# Out:
# (32415, 8)
#                 keyword            name  ... followers  is_user_verified
# 0  [heart beats issues]      jmbinfosec  ...        61             False
# 1  [heart beats issues]  JayyTheGreat88  ...        11             False
# 2  [heart beats issues]    moonscripter  ...       122             False
# 3  [heart beats issues]  chlowapdasawap  ...        87             False
# 4  [heart beats issues]    Starscream35  ...     15092             False
# 5  [heart beats issues]        payyaboy  ...       607             False
# 6  [heart beats issues]        CureLong  ...        85             False
# 7  [heart beats issues]     ibereesecup  ...       549             False
# 8  [heart beats issues]       leonlopez  ...      9744              True
# 9  [heart beats issues]         XRPLODE  ...         8             False
#
# [10 rows x 8 columns]

# %%
#You should also be aware that the legacy standard Twitter search API (this is what api.search is calling)
#only supports searching back within the past 7 days of Tweets. For a longer period of time you will need 
#to use the Twitter premium 30-day or full-archive search APIs.

#Don't forget to update tweepy with pip install --upgrade git+https://github.com/tweepy/tweepy@master. 
#Then you can use the API with premium feature...

#See the documentation for API.search_30_day and API.search_full_archive
#and the corresponding documentation for the premium search APIs.

#The branch has been deleted since #1294 has been merged into the master branch.
#Until v3.10.0 is released, you can install from the master branch.

#for page in tweepy.Cursor(API.search_30_day, query=query, maxResults=per_page,
# environment_name="AzureDevelopment").pages(page_count):
#https://developer.twitter.com/en/account/environments
#pip install --upgrade git+https://github.com/tweepy/tweepy@master
#https://docs.tweepy.org/en/latest/api.html
#TweepError: {'message': 'Exceeded rate limit', 'sent': '2021-03-31T08:53:39+00:00', 'transactionId': 'a444c3435e3b027d'}

import tweepy
from datetime import datetime,timedelta
import csv
from pandas import DataFrame

access_token = "1344327509727346689-rBKxKZ7vkyhF1aeDiJ3MgDj0j5RJQX"
access_token_secret = "eHfV9kN35pV0wz8R4X2QyGQIqlI59i5oKa4UExcK9ZY2G"
consumer_key = "TbTZg3qTpc6APBqiVPKXagu44"
consumer_secret = "RDwln9OnfSNV4SIuLz37oI5KJ7SB63QPdTLpE1Q7imyY9RJgQr"

# later we need to specify fields also, filter retweets before too using fields, expand search period for testing performance using tweeby 3.10 30 days method

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

data = [] # empty list to which tweet_details obj will be added
def stream_tweets(dict):
  #  csvFile = open('output.csv', 'a')
  #  csvWriter = csv.writer(csvFile)
    counter = 0 # counter to keep track of each iteration
#search_terms = 'heart diseases'
    for keyword in dict:
        print ("[+] Checking tweets for keyword:", keyword)
        for status in tweepy.Cursor(api.search_30_day,
                       query="ammar " ,
                       fromDate='202103250000', toDate='202103251000',
                       maxResults=100,
                       wait_on_rate_limit=True,
                       environment_name='HeartDiseasesMonthly').items():

            eastern_time = status.created_at - timedelta(5)
            edt_time = eastern_time.strftime('%Y-%m-%d %H:%M')
        #    csvWriter.writerow([keyword,status.created_at, status.user.screen_name.encode('utf8'), status.text.encode('utf-8')])
            tweet_details = {}
            tweet_details['keyword'] = keyword
            tweet_details['name'] = status.user.screen_name
            tweet_details['tweet'] = status.text
            tweet_details['retweets'] = status.retweet_count
            tweet_details['location'] = status.user.location
            tweet_details['created'] = status.created_at.strftime("%d-%b-%Y")
            tweet_details['followers'] = status.user.followers_count
            tweet_details['is_user_verified'] = status.user.verified
            data.append(tweet_details)
            counter += 1
            if counter % 1000 ==0:
                print(counter)
  #  csvFile.close()
    print('done!')

stream_tweets(dict)
df = DataFrame (data)
print(df.shape)
df.drop_duplicates(subset ="tweet",keep = False, inplace = True)
print(df.shape)
df.head(10)
# Out:
# [+] Checking tweets for keyword: ['heart diseases Myths']
# [+] Checking tweets for keyword: ['heart beats issues']
# 1000
# [+] Checking tweets for keyword: ['cornory heart disease']
# 2000
# [+] Checking tweets for keyword: ['weak heart']
# [+] Checking tweets for keyword: ['irregular heartbeats']
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-20-4c8f96328187> in <module>()
#      68     print('done!')
#      69
# ---> 70 stream_tweets(dict)
#      71 df = DataFrame (data)
#      72 print(df.shape)
#
# <ipython-input-20-4c8f96328187> in stream_tweets(dict)
#      47                        maxResults=100,
#      48                        wait_on_rate_limit=True,
# ---> 49                        environment_name='HeartDiseasesMonthly').items():
#      50
#      51             eastern_time = status.created_at - timedelta(5)
#
# ...

# %%
#You should also be aware that the legacy standard Twitter search API (this is what api.search is calling)
#only supports searching back within the past 7 days of Tweets. For a longer period of time you will need 
#to use the Twitter premium 30-day or full-archive search APIs.

#Don't forget to update tweepy with pip install --upgrade git+https://github.com/tweepy/tweepy@master. 
#Then you can use the API with premium feature...

#See the documentation for API.search_30_day and API.search_full_archive
#and the corresponding documentation for the premium search APIs.

#The branch has been deleted since #1294 has been merged into the master branch.
#Until v3.10.0 is released, you can install from the master branch.

#for page in tweepy.Cursor(API.search_30_day, query=query, maxResults=per_page,
# environment_name="AzureDevelopment").pages(page_count):
#https://developer.twitter.com/en/account/environments
#pip install --upgrade git+https://github.com/tweepy/tweepy@master
#https://docs.tweepy.org/en/latest/api.html
#TweepError: {'message': 'Exceeded rate limit', 'sent': '2021-03-31T08:53:39+00:00', 'transactionId': 'a444c3435e3b027d'}

#https://developer.twitter.com/en/docs/twitter-api/enterprise/rules-and-filtering/operators-by-product
# is:retweet has:videos has:images has:media has:links has:hashtags is:quote
# smart search options like  	(snow OR cold OR blizzard) weather becuase also 
#Rule length exceeds the max allowable. The max is 256 and this rule is 370 (query length limited also)

#https://developer.twitter.com/en/docs/twitter-api/premium/search-api/api-reference/premium-search
#Request rate limits at both minute and second granularity. The per minute rate limit is 
#60 requests per minute (30 with Sandbox environment). Requests are also limited to 10 per second.
#Requests are aggregated across both the data and counts endpoints.
#Monthly request limits are also applied. Sandbox environments are limited to 250 requests per month,
#and paid access can range between 500 and 10,000 requests.

import tweepy
from datetime import datetime,timedelta
import csv
from pandas import DataFrame

access_token = "1344327509727346689-rBKxKZ7vkyhF1aeDiJ3MgDj0j5RJQX"
access_token_secret = "eHfV9kN35pV0wz8R4X2QyGQIqlI59i5oKa4UExcK9ZY2G"
consumer_key = "TbTZg3qTpc6APBqiVPKXagu44"
consumer_secret = "RDwln9OnfSNV4SIuLz37oI5KJ7SB63QPdTLpE1Q7imyY9RJgQr"

# expand search period for testing performance using tweeby 3.10 30 days method + try diffierent python packages + try smart search query options

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

data = [] # empty list to which tweet_details obj will be added
def stream_tweets(dict):
  #  csvFile = open('output.csv', 'a')
  #  csvWriter = csv.writer(csvFile)
    counter = 0 # counter to keep track of each iteration
#search_terms = 'heart diseases'
#    for keyword in dict:
#     print ("[+] Checking tweets for keyword:", keyword)
    for status in tweepy.Cursor(api.search_30_day,
                       query="heart diseases Myths OR heart beats issues OR cornory heart disease \
OR weak heart  OR irregular heartbeats OR Congenital heart defects OR heart defects OR heart birth issues \
OR ischemic heart disease OR cardiovascular diseases" ,
                       fromDate='202103170000', toDate='202103191500',
                       maxResults=100,
                       wait_on_rate_limit=True,
                       environment_name='HeartDiseasesMonthly').items():

          eastern_time = status.created_at - timedelta(5)
          edt_time = eastern_time.strftime('%Y-%m-%d %H:%M')
        #    csvWriter.writerow([keyword,status.created_at, status.user.screen_name.encode('utf8'), status.text.encode('utf-8')])
          tweet_details = {}
         # tweet_details['keyword'] = keyword
          tweet_details['name'] = status.user.screen_name
          tweet_details['tweet'] = status.text
          tweet_details['retweets'] = status.retweet_count
          tweet_details['location'] = status.user.location
          tweet_details['created'] = status.created_at.strftime("%d-%b-%Y")
          tweet_details['followers'] = status.user.followers_count
          tweet_details['is_user_verified'] = status.user.verified
          data.append(tweet_details)
          counter += 1
          if counter % 1000 ==0:
              print(counter)
  #  csvFile.close()
    print('done!')


stream_tweets(dict)
df = DataFrame (data)
print(df.shape)
df.drop_duplicates(subset ="tweet",keep = False, inplace = True)
print(df.shape)
df.head(10)
# Out:
# 1000
# 2000
# 3000
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-40-2283b3c867f9> in <module>()
#      84
#      85
# ---> 86 stream_tweets(dict)
#      87 df = DataFrame (data)
#      88 print(df.shape)
#
# <ipython-input-40-2283b3c867f9> in stream_tweets(dict)
#      62                        maxResults=100,
#      63                        wait_on_rate_limit=True,
# ---> 64                        environment_name='HeartDiseasesMonthly').items():
#      65
#      66           eastern_time = status.created_at - timedelta(5)
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in next(self)
# ...

# %%
#You should also be aware that the legacy standard Twitter search API (this is what api.search is calling)
#only supports searching back within the past 7 days of Tweets. For a longer period of time you will need 
#to use the Twitter premium 30-day or full-archive search APIs.

#Don't forget to update tweepy with pip install --upgrade git+https://github.com/tweepy/tweepy@master. 
#Then you can use the API with premium feature...

#See the documentation for API.search_30_day and API.search_full_archive
#and the corresponding documentation for the premium search APIs.

#The branch has been deleted since #1294 has been merged into the master branch.
#Until v3.10.0 is released, you can install from the master branch.

#for page in tweepy.Cursor(API.search_30_day, query=query, maxResults=per_page,
# environment_name="AzureDevelopment").pages(page_count):
#https://developer.twitter.com/en/account/environments
#pip install --upgrade git+https://github.com/tweepy/tweepy@master
#https://docs.tweepy.org/en/latest/api.html
#TweepError: {'message': 'Exceeded rate limit', 'sent': '2021-03-31T08:53:39+00:00', 'transactionId': 'a444c3435e3b027d'}

#https://developer.twitter.com/en/docs/twitter-api/enterprise/rules-and-filtering/operators-by-product
# is:retweet has:videos has:images has:media has:links has:hashtags is:quote
# smart search options like  	(snow OR cold OR blizzard) weather becuase also 
#Rule length exceeds the max allowable. The max is 256 and this rule is 370 (query length limited also)

#https://developer.twitter.com/en/docs/twitter-api/premium/search-api/api-reference/premium-search
#Request rate limits at both minute and second granularity. The per minute rate limit is 
#60 requests per minute (30 with Sandbox environment). Requests are also limited to 10 per second.
#Requests are aggregated across both the data and counts endpoints.
#Monthly request limits are also applied. Sandbox environments are limited to 250 requests per month,
#and paid access can range between 500 and 10,000 requests.

# expand search period for testing performance using tweeby 3.10 30 days method + try diffierent python packages + try smart search query options

import tweepy
from datetime import datetime,timedelta
import csv
from pandas import DataFrame

access_token = "1344327509727346689-rBKxKZ7vkyhF1aeDiJ3MgDj0j5RJQX"
access_token_secret = "eHfV9kN35pV0wz8R4X2QyGQIqlI59i5oKa4UExcK9ZY2G"
consumer_key = "TbTZg3qTpc6APBqiVPKXagu44"
consumer_secret = "RDwln9OnfSNV4SIuLz37oI5KJ7SB63QPdTLpE1Q7imyY9RJgQr"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

cursory= tweepy.Cursor(api.search_30_day,
                       query="heart diseases Myths OR heart beats issues OR cornory heart disease \
OR weak heart  OR irregular heartbeats OR Congenital heart defects OR heart defects OR heart birth issues \
OR ischemic heart disease OR cardiovascular diseases" ,
                       fromDate='202103170000', toDate='202103191500',
                       maxResults=100,
                       wait_on_rate_limit=True,
                       environment_name='HeartDiseasesMonthly').items()

data = [] # empty list to which tweet_details obj will be added
counter = 0
for status in cursory:
    eastern_time = status.created_at - timedelta(5)
    edt_time = eastern_time.strftime('%Y-%m-%d %H:%M')
    tweet_details = {}
    tweet_details['name'] = status.user.screen_name
    tweet_details['tweet'] = status.text
    tweet_details['retweets'] = status.retweet_count
    tweet_details['location'] = status.user.location
    tweet_details['created'] = status.created_at.strftime("%d-%b-%Y")
    tweet_details['followers'] = status.user.followers_count
    tweet_details['is_user_verified'] = status.user.verified
    data.append(tweet_details)
    counter += 1
    if counter % 1000 ==0:
      print(counter)
#    except:
#        print("API limit exceeded. Waiting for next hour")
#            time.sleep(3605) # change to 5 for testing
#stream_tweets(dict)
df = DataFrame (data)
print(df.shape)
df.drop_duplicates(subset ="tweet",keep = False, inplace = True)
print(df.shape)
df.head(10)
# Out:
# 1000
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _error_catcher(self)
#     361             try:
# --> 362                 yield
#     363
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     443                 cache_content = False
# --> 444                 data = self._fp.read(amt)
#     445                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /usr/lib/python3.7/http/client.py in read(self, amt)
#     460             b = bytearray(amt)
# --> 461             n = self.readinto(b)
#     462             return memoryview(b)[:n].tobytes()
#
# /usr/lib/python3.7/http/client.py in readinto(self, b)
#     504         # (for example, reading in 1k chunks)
# --> 505         n = self.fp.readinto(b)
# ...

# %%
#You should also be aware that the legacy standard Twitter search API (this is what api.search is calling)
#only supports searching back within the past 7 days of Tweets. For a longer period of time you will need 
#to use the Twitter premium 30-day or full-archive search APIs.

#Don't forget to update tweepy with pip install --upgrade git+https://github.com/tweepy/tweepy@master. 
#Then you can use the API with premium feature...

#See the documentation for API.search_30_day and API.search_full_archive
#and the corresponding documentation for the premium search APIs.

#The branch has been deleted since #1294 has been merged into the master branch.
#Until v3.10.0 is released, you can install from the master branch.

#for page in tweepy.Cursor(API.search_30_day, query=query, maxResults=per_page,
# environment_name="AzureDevelopment").pages(page_count):
#https://developer.twitter.com/en/account/environments
#pip install --upgrade git+https://github.com/tweepy/tweepy@master
#https://docs.tweepy.org/en/latest/api.html
#TweepError: {'message': 'Exceeded rate limit', 'sent': '2021-03-31T08:53:39+00:00', 'transactionId': 'a444c3435e3b027d'}

#https://developer.twitter.com/en/docs/twitter-api/enterprise/rules-and-filtering/operators-by-product
# is:retweet has:videos has:images has:media has:links has:hashtags is:quote
# smart search options like  	(snow OR cold OR blizzard) weather becuase also 
#Rule length exceeds the max allowable. The max is 256 and this rule is 370 (query length limited also)

#https://developer.twitter.com/en/docs/twitter-api/premium/search-api/api-reference/premium-search
#Request rate limits at both minute and second granularity. The per minute rate limit is 
#60 requests per minute (30 with Sandbox environment). Requests are also limited to 10 per second.
#Requests are aggregated across both the data and counts endpoints.
#Monthly request limits are also applied. Sandbox environments are limited to 250 requests per month,
#and paid access can range between 500 and 10,000 requests.

# expand search period for testing performance using tweeby 3.10 30 days method + try diffierent python packages + try smart search query options

import tweepy
import time
from time import sleep
from datetime import datetime,timedelta
import csv
from pandas import DataFrame

access_token = "1344327509727346689-rBKxKZ7vkyhF1aeDiJ3MgDj0j5RJQX"
access_token_secret = "eHfV9kN35pV0wz8R4X2QyGQIqlI59i5oKa4UExcK9ZY2G"
consumer_key = "TbTZg3qTpc6APBqiVPKXagu44"
consumer_secret = "RDwln9OnfSNV4SIuLz37oI5KJ7SB63QPdTLpE1Q7imyY9RJgQr"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
#Coronary artery disease
#Coronary artery disease treatment
#Coronary artery disease symptoms
#heart disease
#heart attack
#heart attack causes
#heart attack symptoms
#heart attack treatment
#heart disease causes
#heart disease symptoms
#heart disease treatment

cursory= tweepy.Cursor(api.search_30_day,
                       query="Coronary artery disease OR heart disease treatment OR Coronary artery disease symptoms \
OR heart disease  OR heart attack OR heart attack causes OR heart attack symptoms OR heart attack treatment \
OR heart disease causes OR heart disease symptoms" ,
                       fromDate='202106010000', toDate='202105011500',
                       maxResults=100,
                       wait_on_rate_limit=True,
                       environment_name='HeartDiseasesMonthly').items()

data = [] # empty list to which tweet_details obj will be added
counter = 0

backoff_counter = 1
while True:
    try:
        status = cursory.next()
        eastern_time = status.created_at - timedelta(5)
        edt_time = eastern_time.strftime('%Y-%m-%d %H:%M')
        tweet_details = {}
        tweet_details['name'] = status.user.screen_name
        tweet_details['tweet'] = status.text
        tweet_details['retweets'] = status.retweet_count
        tweet_details['location'] = status.user.location
        tweet_details['created'] = status.created_at.strftime("%d-%b-%Y")
        tweet_details['followers'] = status.user.followers_count
        tweet_details['is_user_verified'] = status.user.verified
        data.append(tweet_details)
        counter += 1
        if counter % 1000 ==0:
           print(counter)
    except tweepy.TweepError:
        time.sleep(60 * backoff_counter)
        backoff_counter += 1
        continue
    except StopIteration:
        break

df = DataFrame (data)
print(df.shape)
df.drop_duplicates(subset ="tweet",keep = False, inplace = True)
print(df.shape)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-19-f1a2291a9a09> in <module>()
#      76     try:
# ---> 77         status = cursory.next()
#      78         eastern_time = status.created_at - timedelta(5)
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in next(self)
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in next(self)
#     215             raise StopIteration
# --> 216         data = self.method(next=self.next_token, return_cursors=True, *self.args, **self.kwargs)
#     217         self.page_count += 1
#
# /usr/local/lib/python3.7/dist-packages/tweepy/api.py in search_30_day(self, environment_name, *args, **kwargs)
# ...

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df['tweet']
# Out:
# 0                                                                                          my heart is too weak to take it ㅠㅠ https://t.co/8o4U7yV4Pa
# 1        "Jungkook, go away" he hears is muffled voice from the other side and Jungkook's heart crumbles at how weak he soun… https://t.co/IICYifq6Ic
# 5         Alexa, do I have an abnormal heart rhythm? UW researchers use AI and smart speakers to monitor irregular heartbeats https://t.co/SSoln9vS7S
# 7       Facts for #bvprockyoursocks #Rockyoursocks from NDSS: \nPeople with Down syndrome have an increased risk for certain… https://t.co/REQAEPsnIn
# 9        RT @jwooseternal: Aaaaaaaah this is so cute the way Jungwoo grabbed Jaehyun's arm while laughing🥺 my jaewoo heart is so weak pls #잰정 https:…
#                                                                             ...
# 3155                                                                                     @9NewsSyd Don’t scare me with the title. I have a weak heart
# ...
